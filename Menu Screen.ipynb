# %%
import subprocess
import pygame
import sys
#import (Working snake and apple game)

# initializing the constructor
pygame.init()

# screen resolution
res = (720,720)

# opens up a window
screen = pygame.display.set_mode(res)

# white color
color = ('red')

# light shade of the button
color_light = (170,170,170)

# dark shade of the button
color_dark = (100,100,100)

# stores the width of the
# screen into a variable
width = screen.get_width()

# stores the height of the
# screen into a variable
height = screen.get_height()

# defining a font
smallfont = pygame.font.SysFont('Corbel',35)

# rendering a text written in
# this font
text = smallfont.render('Snake and Apple' , True , color)

while True:
	
	for ev in pygame.event.get():
		
		if ev.type == pygame.QUIT:
			pygame.quit()
		if ev.type == pygame.MOUSEBUTTONDOWN:
			if width/2 <= mouse[0] <= width/2+140 and height/2 <= mouse[1] <= height/2+40:
				subprocess.system('python Working snake and apple.py')
				
	# fills the screen with a color
	screen.fill((255,255,255))
	
	# stores the (x,y) coordinates into
	# the variable as a tuple
	mouse = pygame.mouse.get_pos()
	
	# if mouse is hovered on a button it
	# changes to lighter shade
	if width/2 <= mouse[0] <= width/2+140 and height/2 <= mouse[1] <= height/2+40:
		pygame.draw.rect(screen,color_light,[width/2,height/2,140,40])
		
	else:
		pygame.draw.rect(screen,color_dark,[width/2,height/2,140,40])
	
	# superimposing the text onto our button
	screen.blit(text , (width/2+50,height/2))
	
	# updates the frames of the game
	pygame.display.update()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22248/2602200481.py in <module>
#      45                 if ev.type == pygame.MOUSEBUTTONDOWN:
#      46                         if width/2 <= mouse[0] <= width/2+140 and height/2 <= mouse[1] <= height/2+40:
# ---> 47                                 subprocess.system('python Working snake and apple.py')
#      48
#      49         # fills the screen with a color
#
# AttributeError: module 'subprocess' has no attribute 'system'
# ...

# %%
#exec(compile(open, "rb").read(), filename, 'exec')	
				#exec('Tic Tac Toe single and double working copy.ipynb')
		"""with open('Working snake and apple game.py') as infile:
                    exec(infile.read())"""
		"""def exec_full(filepath):
					global_namespace = {
						"__file__": filepath,
						"__name__": "__main__",
					}
					with open(filepath, 'rb') as file:
						exec(compile(file.read(), filepath, 'exec'), global_namespace)

				# Execute the file.
				exec_full("/path/to/Working snake and apple game copy.py")"""
